# %%
import pandas as pd

df= pd.read_csv('dataset preprocessing + stemming.csv')
s= pd.Series(df['label'])

# %%
s.isnull().values.any()
# Out:
# True

# %%
s.isnull().sum()
# Out:
# 2

# %%
s
# Out:
# 0       negatif
# 1       negatif
# 2       negatif
# 3       negatif
# 4       negatif
#          ...
# 1167    negatif
# 1168    negatif
# 1169     netral
# 1170     netral
# 1171     netral
# Name: label, Length: 1172, dtype: object

# %%
s.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1167    False
# 1168    False
# 1169    False
# 1170    False
# 1171    False
# Name: label, Length: 1172, dtype: bool

# %%
print(s.to_string())
# Out:
# 0       negatif
# 1       negatif
# 2       negatif
# 3       negatif
# 4       negatif
# 5       negatif
# 6       negatif
# 7       negatif
# 8        netral
# 9        netral
# 10      negatif
# 11      negatif
# 12      negatif
# 13      positif
# 14      negatif
# 15      negatif
# 16       netral
# 17       netral
# 18      negatif
# 19       netral
# 20      negatif
# 21      negatif
# 22       netral
# 23      negatif
# 24      negatif
# 25       netral
# 26       netral
# 27      negatif
# 28      negatif
# 29      negatif
# 30       netral
# 31      negatif
# 32      negatif
# 33       netral
# 34       netral
# 35      negatif
# 36       netral
# 37       netral
# 38      negatif
# 39      negatif
# 40      negatif
# 41      negatif
# 42      positif
# 43      negatif
# 44      negatif
# 45      negatif
# 46      negatif
# 47      positif
# 48      negatif
# 49       netral
# 50      positif
# 51      negatif
# 52      positif
# 53       netral
# 54      positif
# ...
